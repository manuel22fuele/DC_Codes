# %% [markdown]
# ### Creating the machine learning algorithm

# %% [markdown]
# #### Import the relavant lib

# %%
import numpy as np 
import tensorflow as tf

# %% [markdown]
# #### Data

# %%
npz = np.load('Audiobooks file/Audiobooks_data_train.npz')

train_inputs, train_targets = npz['inputs'].astype(np.float64), npz['targets'].astype(np.int32) 

npz = np.load('Audiobooks file/Audiobooks_data_validation.npz')

validation_inputs, validation_targets = npz['inputs'].astype(np.float64), npz['targets'].astype(np.int32)

npz = np.load('Audiobooks file/Audiobooks_data_test.npz')

test_inputs, test_targets = npz['inputs'].astype(np.float64), npz['targets'].astype(np.int32)

# %% [markdown]
# #### Model

# %% [markdown]
# ##### Outline, optimizers, loss, early stopping and training

# %%
input_size = 10
output_size = 2
hidden_layer = 50

early_stopping = tf.keras.callbacks.EarlyStopping(patience=2) # By default this object will monitor the validation loss and stop the training process the first time the validation loss starts increasing
 
model = tf.keras.Sequential([
                              tf.keras.layers.Dense(hidden_layer, activation='relu'),
                              tf.keras.layers.Dense(hidden_layer, activation='relu'),
                              tf.keras.layers.Dense(output_size, activation='softmax')
     
 ])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

BATCH_SIZE = 100
MAX_EPOCHS = 100

model.fit(
    train_inputs,
    train_targets,
    batch_size = BATCH_SIZE,
    epochs = MAX_EPOCHS,
    callbacks=[early_stopping],
    validation_data = (validation_inputs, validation_targets),
    verbose = 2
)
# Out:
# Epoch 1/100
# 36/36 - 6s - 163ms/step - accuracy: 0.6410 - loss: 0.6352 - val_accuracy: 0.7763 - val_loss: 0.5255
# Epoch 2/100
# 36/36 - 0s - 11ms/step - accuracy: 0.7580 - loss: 0.4897 - val_accuracy: 0.7897 - val_loss: 0.4253
# Epoch 3/100
# 36/36 - 0s - 11ms/step - accuracy: 0.7706 - loss: 0.4332 - val_accuracy: 0.8009 - val_loss: 0.3854
# Epoch 4/100
# 36/36 - 0s - 10ms/step - accuracy: 0.7888 - loss: 0.4058 - val_accuracy: 0.8076 - val_loss: 0.3656
# Epoch 5/100
# 36/36 - 0s - 10ms/step - accuracy: 0.7924 - loss: 0.3916 - val_accuracy: 0.8166 - val_loss: 0.3591
# Epoch 6/100
# 36/36 - 0s - 10ms/step - accuracy: 0.7904 - loss: 0.3867 - val_accuracy: 0.8121 - val_loss: 0.3482
# Epoch 7/100
# 36/36 - 0s - 11ms/step - accuracy: 0.8022 - loss: 0.3776 - val_accuracy: 0.8188 - val_loss: 0.3520
# Epoch 8/100
# 36/36 - 1s - 18ms/step - accuracy: 0.7994 - loss: 0.3731 - val_accuracy: 0.8121 - val_loss: 0.3438
# Epoch 9/100
# 36/36 - 0s - 10ms/step - accuracy: 0.8075 - loss: 0.3687 - val_accuracy: 0.8255 - val_loss: 0.3376
# Epoch 10/100
# 36/36 - 0s - 10ms/step - accuracy: 0.8053 - loss: 0.3666 - val_accuracy: 0.8166 - val_loss: 0.3376
# Epoch 11/100
# 36/36 - 0s - 10ms/step - accuracy: 0.8078 - loss: 0.3638 - val_accuracy: 0.8322 - val_loss: 0.3343
# Epoch 12/100
# 36/36 - 0s - 9ms/step - accuracy: 0.8030 - loss: 0.3642 - val_accuracy: 0.8345 - val_loss: 0.3293
# Epoch 13/100
# 36/36 - 0s - 9ms/step - accuracy: 0.8131 - loss: 0.3618 - val_accuracy: 0.8166 - val_loss: 0.3364
# Epoch 14/100
# 36/36 - 0s - 11ms/step - accuracy: 0.8108 - loss: 0.3590 - val_accuracy: 0.8210 - val_loss: 0.3280
# Epoch 15/100
# 36/36 - 0s - 11ms/step - accuracy: 0.8089 - loss: 0.3579 - val_accuracy: 0.8300 - val_loss: 0.3230
# Epoch 16/100
# 36/36 - 0s - 10ms/step - accuracy: 0.8069 - loss: 0.3534 - val_accuracy: 0.8255 - val_loss: 0.3297
# Epoch 17/100
# 36/36 - 0s - 10ms/step - accuracy: 0.8069 - loss: 0.3548 - val_accuracy: 0.8300 - val_loss: 0.3203
# Epoch 18/100
# 36/36 - 0s - 10ms/step - accuracy: 0.8136 - loss: 0.3513 - val_accuracy: 0.8322 - val_loss: 0.3222
# Epoch 19/100
# 36/36 - 0s - 10ms/step - accuracy: 0.8097 - loss: 0.3520 - val_accuracy: 0.8300 - val_loss: 0.3244

# %% [markdown]
# ### Testing the model

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8013 - loss: 0.3849

# %%
print('Test loss: {:.2f}%. Test accuracy: {:.2f}%'. format(test_loss, test_accuracy*100))
# Out:
# Test loss: 0.38%. Test accuracy: 80.13%

# %%
import pandas as pd

# %%
raw_csv_data = pd.read_csv('Absenteeism_data.csv')

# %%
df = raw_csv_data.copy()

# %%
df
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 0    11                  26  07/07/2015                     289
# 1    36                   0  14/07/2015                     118
# 2     3                  23  15/07/2015                     179
# 3     7                   7  16/07/2015                     279
# 4    11                  23  23/07/2015                     289
# ..   ..                 ...         ...                     ...
# 695  17                  10  23/05/2018                     179
# 696  28                   6  23/05/2018                     225
# 697  18                  10  24/05/2018                     330
# 698  25                  23  24/05/2018                     235
# 699  15                  28  31/05/2018                     291
#
#      Distance to Work  Age  Daily Work Load Average  Body Mass Index  \
# 0                  36   33                  239.554               30
# 1                  13   50                  239.554               31
# 2                  51   38                  239.554               31
# 3                   5   39                  239.554               24
# 4                  36   33                  239.554               30
# ..                ...  ...                      ...              ...
# 695                22   40                  237.656               22
# 696                26   28                  237.656               24
# 697                16   28                  237.656               25
# 698                16   32                  237.656               25
# 699                31   40                  237.656               25
#
#      Education  Children  Pets  Absenteeism Time in Hours
# 0            1         2     1                          4
# 1            1         1     0                          0
# 2            1         0     0                          2
# 3            1         2     0                          4
# 4            1         2     1                          2
# ..         ...       ...   ...                        ...
# 695          2         2     0                          8
# 696          1         1     2                          3
# 697          2         0     0                          8
# 698          3         0     0                          2
# 699          1         1     1                          2
#
# [700 rows x 12 columns]

# %% [markdown]
# ### Drop 'ID'

# %%
df = df.drop(['ID'], axis = 1)

# %% [markdown]
# ### Drop 'Age'

# %%
df_no_age = df.drop(['Age'], axis = 1)

# %%
age_dummies = pd.get_dummies(df['Age'])

# %%
age_dummies
# Out:
#         27     28     29     30     31     32     33     34     36     37  \
# 0    False  False  False  False  False  False   True  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False   True  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 695  False  False  False  False  False  False  False  False  False  False
# 696  False   True  False  False  False  False  False  False  False  False
# 697  False   True  False  False  False  False  False  False  False  False
# 698  False  False  False  False  False   True  False  False  False  False
# 699  False  False  False  False  False  False  False  False  False  False
#
#      ...     39     40     41     43     46     47     48     49     50     58
# 0    ...  False  False  False  False  False  False  False  False  False  False
# 1    ...  False  False  False  False  False  False  False  False   True  False
# 2    ...  False  False  False  False  False  False  False  False  False  False
# 3    ...   True  False  False  False  False  False  False  False  False  False
# 4    ...  False  False  False  False  False  False  False  False  False  False
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 695  ...  False   True  False  False  False  False  False  False  False  False
# 696  ...  False  False  False  False  False  False  False  False  False  False
# 697  ...  False  False  False  False  False  False  False  False  False  False
# 698  ...  False  False  False  False  False  False  False  False  False  False
# 699  ...  False   True  False  False  False  False  False  False  False  False
#
# [700 rows x 21 columns]

# %%
age_dummies['check'] = age_dummies.sum(axis=1)
age_dummies
# Out:
#         27     28     29     30     31     32     33     34     36     37  \
# 0    False  False  False  False  False  False   True  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False   True  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 695  False  False  False  False  False  False  False  False  False  False
# 696  False   True  False  False  False  False  False  False  False  False
# 697  False   True  False  False  False  False  False  False  False  False
# 698  False  False  False  False  False   True  False  False  False  False
# 699  False  False  False  False  False  False  False  False  False  False
#
#      ...     40     41     43     46     47     48     49     50     58  check
# 0    ...  False  False  False  False  False  False  False  False  False      1
# 1    ...  False  False  False  False  False  False  False   True  False      1
# 2    ...  False  False  False  False  False  False  False  False  False      1
# 3    ...  False  False  False  False  False  False  False  False  False      1
# 4    ...  False  False  False  False  False  False  False  False  False      1
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 695  ...   True  False  False  False  False  False  False  False  False      1
# 696  ...  False  False  False  False  False  False  False  False  False      1
# 697  ...  False  False  False  False  False  False  False  False  False      1
# 698  ...  False  False  False  False  False  False  False  False  False      1
# 699  ...   True  False  False  False  False  False  False  False  False      1
#
# [700 rows x 22 columns]

# %%
age_dummies['check'].sum(axis=0)
# Out:
# np.int64(700)

# %%
age_dummies['check'].unique()
# Out:
# array([1])

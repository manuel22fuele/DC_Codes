# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np

# %% [markdown]
# ## Declaring scalars, vectors, and matrices

# %% [markdown]
# ### Scalars

# %%
s = 5

# %%
s
# Out:
# 5

# %% [markdown]
# ### Vectors

# %%
v = np.array([5,-2,4])

# %%
v
# Out:
# array([ 5, -2,  4])

# %% [markdown]
# ### Matrices

# %%
m = np.array([[5, 12, 6],
             [-3, 0, 14]])

# %%
m
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %% [markdown]
# ### Data types

# %%
type(s)
# Out:
# int

# %%
type(v)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Data shapes

# %%
m.shape
# Out:
# (2, 3)

# %%
v.shape
# Out:
# (3,)

# %% [markdown]
#  # Tensor

# %% [markdown]
# ### Creating a tensor

# %%
m1 = np.array([[5,12,6],
               [-3,0,14]])
m1
# Out:
# array([[ 5, 12,  6],
#        [-3,  0, 14]])

# %%
m2 = np.array([[9,8,7],
               [1,3,-5]])
m2
# Out:
# array([[ 9,  8,  7],
#        [ 1,  3, -5]])

# %%
t = np.array([m1, m2])
t
# Out:
# array([[[ 5, 12,  6],
#         [-3,  0, 14]],
#
#        [[ 9,  8,  7],
#         [ 1,  3, -5]]])

# %%
t.shape
# Out:
# (2, 2, 3)

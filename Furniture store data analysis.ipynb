# %% [markdown]
# Hi ChatGPT, I have the following four datasets and columns: customers - customer_id name products - product_id product_name price category ratings - customer_id product_id order_date quantity orders - order_id customer_id product_id order_date quantity I wish to analyse the data, and find out the top performing products in terms of revenue, as well as in terms of how many units have been sold, and identify top clients for the last month. can you provide me with python code to achieve this?

# %%
import pandas as pd

# customers, products, ratings, orders files
customers = pd.read_csv('customers.csv')
products = pd.read_csv('products.csv')
ratings = pd.read_csv('ratings.csv')
orders = pd.read_csv('orders.csv')


# --- Step 1: Merge orders with products to get price ---
orders_merged = orders.merge(products, on="product_id", how="left")


# --- Step 2: Calculate revenue for each order ---
orders_merged["revenue"] = orders_merged["quantity"] * orders_merged["price"]
# Out:
#      order_id  customer_id  product_id                  order_date  quantity  \
# 0           1           66          38  2023-08-09 08:39:23.971834         4
# 1           2           10          29  2023-09-08 08:39:23.971834         4
# 2           3           58           9  2023-07-29 08:39:23.971834         3
# 3           4           33          44  2023-09-13 08:39:23.971834         4
# 4           5           32          47  2023-07-24 08:39:23.971834         2
# ..        ...          ...         ...                         ...       ...
# 995       996           30          42  2023-08-15 08:39:23.971834         4
# 996       997            3          16  2023-09-11 08:39:23.971834         2
# 997       998           84          29  2023-09-05 08:39:23.971834         2
# 998       999           77          43  2023-08-13 08:39:23.971834         4
# 999      1000           19          32  2023-09-07 08:39:23.971834         3
#
#                 product_name  price           category  revenue
# 0    Bekant Conference Table    441     Tables & Desks     1764
# 1               Råskog Stool    855             Chairs     3420
# 2                 Micke Desk     19     Tables & Desks       57
# 3            Koppang Dresser    765              Decor     3060
# 4            Nymö Lamp Shade    157           Lighting      314
# ..                       ...    ...                ...      ...
# 995         Småstad Wardrobe    994  Storage Solutions     3976
# 996              Ranarp Lamp    482           Lighting      964
# 997             Råskog Stool    855             Chairs     1710
# 998      Sjöpenna Floor Lamp    187           Lighting      748
# 999             Kivik Chaise    926  Sofas & Armchairs     2778
#
# [1000 rows x 9 columns]

# %%
# --- Step 3: Get last month filter ---
orders_merged["order_date"] = pd.to_datetime(orders_merged["order_date"])
last_month = orders_merged["order_date"].max().to_period("M")
orders_last_month = orders_merged[orders_merged["order_date"].dt.to_period("M") == last_month]


# --- Step 4: Top products by revenue ---
top_products_revenue = (
orders_last_month.groupby(["product_id", "product_name"])
["revenue"].sum()
.sort_values(ascending=False)
.reset_index()
)

top_products_revenue
# Out:
#     product_id             product_name  revenue
# 0           26            Docksta Table    21475
# 1           34       Fjälla Storage Box    17748
# 2           31             Nockeby Sofa    17314
# 3           49   Söderhamn Sofa Section    16454
# 4            1              Ektorp Sofa    15268
# 5           42         Småstad Wardrobe    14910
# 6            5            Hemnes Daybed    14365
# 7            6      Brimnes Bed Storage    13914
# 8           37              Fredde Desk    13712
# 9            3         Klippan Loveseat    12780
# 10          13      Terje Folding Chair    12210
# 11          46       Valje Wall Cabinet    12042
# 12          29             Råskog Stool    11970
# 13          48           Bestå TV Bench    11960
# 14          40         Lommarp Bookcase    10320
# 15          44          Koppang Dresser     9180
# 16          35     Rugveda Coffee Table     9180
# 17          16              Ranarp Lamp     8676
# 18          36         Gronlid Armchair     8628
# 19          32             Kivik Chaise     8334
# 20          10     Kallax Shelving Unit     8063
# 21           2           Poäng Armchair     7966
# 22          38  Bekant Conference Table     7938
# 23          12           Raskog Trolley     7640
# 24          17   Sinnerlig Pendant Lamp     7320
# 25          21         Stockholm Mirror     6944
# 26          39    Mackapar Shoe Storage     6870
# 27           7          Lack Side Table     5736
# 28           8    Melltorp Dining Table     5535
# 29          50         Mörbylånga Table     5364
# 30          25       Rens Sheepskin Rug     4880
# 31          45         Hektar Work Lamp     4842
# 32          27             Ivar Cabinet     4809
# 33          22     Nordli Chest Drawers     3927
# 34          28         Tarva Nightstand     3829
# 35          14         Ingolf Bar Stool     3654
# 36          11           Billy Bookcase     3157
# 37          43      Sjöpenna Floor Lamp     2992
# 38          19              Ribba Frame     2916
# 39          18      Skurup Ceiling Lamp     2842
# 40          47          Nymö Lamp Shade     2669
# 41          24         Askvoll Wardrobe     2576
# 42          20        Pjatteryd Picture     2145
# 43          30     Strandmon Wing Chair     1230
# 44           4           Malm Bed Frame     1212
# 45          41        Tingby Side Table     1090
# 46          15           Bernhard Chair      800
# 47          23           Stuva Loft Bed      485
# 48          33            Lerhamn Chair      375
# 49           9               Micke Desk      152

# %%
# --- Step 5: Top products by units sold ---
top_products_units = (
orders_last_month.groupby(["product_id", "product_name"])
["quantity"].sum()
.sort_values(ascending=False)
.reset_index()
)

top_products_units
# Out:
#     product_id             product_name  quantity
# 0           49   Söderhamn Sofa Section        38
# 1           26            Docksta Table        25
# 2           31             Nockeby Sofa        22
# 3            1              Ektorp Sofa        22
# 4            3         Klippan Loveseat        20
# 5           50         Mörbylånga Table        18
# 6           16              Ranarp Lamp        18
# 7           46       Valje Wall Cabinet        18
# 8           38  Bekant Conference Table        18
# 9           34       Fjälla Storage Box        18
# 10           6      Brimnes Bed Storage        18
# 11          47          Nymö Lamp Shade        17
# 12           5            Hemnes Daybed        17
# 13          37              Fredde Desk        16
# 14          43      Sjöpenna Floor Lamp        16
# 15          13      Terje Folding Chair        15
# 16          39    Mackapar Shoe Storage        15
# 17           8    Melltorp Dining Table        15
# 18          42         Småstad Wardrobe        15
# 19          30     Strandmon Wing Chair        15
# 20          29             Råskog Stool        14
# 21          21         Stockholm Mirror        14
# 22          24         Askvoll Wardrobe        14
# 23           2           Poäng Armchair        14
# 24          48           Bestå TV Bench        13
# 25          44          Koppang Dresser        12
# 26          36         Gronlid Armchair        12
# 27          35     Rugveda Coffee Table        12
# 28          40         Lommarp Bookcase        12
# 29          17   Sinnerlig Pendant Lamp        12
# 30          11           Billy Bookcase        11
# 31          10     Kallax Shelving Unit        11
# 32          12           Raskog Trolley        10
# 33          41        Tingby Side Table        10
# 34          15           Bernhard Chair        10
# 35          19              Ribba Frame         9
# 36          32             Kivik Chaise         9
# 37          25       Rens Sheepskin Rug         8
# 38           9               Micke Desk         8
# 39           7          Lack Side Table         8
# 40          28         Tarva Nightstand         7
# 41          27             Ivar Cabinet         7
# 42          22     Nordli Chest Drawers         7
# 43          18      Skurup Ceiling Lamp         7
# 44           4           Malm Bed Frame         6
# 45          45         Hektar Work Lamp         6
# 46          14         Ingolf Bar Stool         6
# 47          23           Stuva Loft Bed         5
# 48          33            Lerhamn Chair         3
# 49          20        Pjatteryd Picture         3

# %%
# --- Step 6: Top clients by revenue ---
top_clients = (
orders_last_month.groupby(["customer_id"])
["revenue"].sum()
.sort_values(ascending=False)
.reset_index()
.merge(customers, on="customer_id", how="left")
)

top_clients
# Out:
#     customer_id  revenue         name
# 0            44    13819  Customer_44
# 1             1    12685   Customer_1
# 2            33    11073  Customer_33
# 3            18    11053  Customer_18
# 4            52     9355  Customer_52
# ..          ...      ...          ...
# 91           61      471  Customer_61
# 92           20      458  Customer_20
# 93           90      444  Customer_90
# 94           80      291  Customer_80
# 95           13      287  Customer_13
#
# [96 rows x 3 columns]

# %%
# --- Step 7: Display results ---
print("Top products by revenue last month:")
print(top_products_revenue.head(10))


print("\nTop products by units sold last month:")
print(top_products_units.head(10))


print("\nTop clients by revenue last month:")
print(top_clients.head(10))
# Out:
# Top products by revenue last month:
#    product_id            product_name  revenue
# 0          26           Docksta Table    21475
# 1          34      Fjälla Storage Box    17748
# 2          31            Nockeby Sofa    17314
# 3          49  Söderhamn Sofa Section    16454
# 4           1             Ektorp Sofa    15268
# 5          42        Småstad Wardrobe    14910
# 6           5           Hemnes Daybed    14365
# 7           6     Brimnes Bed Storage    13914
# 8          37             Fredde Desk    13712
# 9           3        Klippan Loveseat    12780
#
# Top products by units sold last month:
#    product_id             product_name  quantity
# 0          49   Söderhamn Sofa Section        38
# 1          26            Docksta Table        25
# 2          31             Nockeby Sofa        22
# 3           1              Ektorp Sofa        22
# 4           3         Klippan Loveseat        20
# 5          50         Mörbylånga Table        18
# 6          16              Ranarp Lamp        18
# 7          46       Valje Wall Cabinet        18
# 8          38  Bekant Conference Table        18
# 9          34       Fjälla Storage Box        18
#
# Top clients by revenue last month:
#    customer_id  revenue         name
# 0           44    13819  Customer_44
# 1            1    12685   Customer_1
# 2           33    11073  Customer_33
# 3           18    11053  Customer_18
# 4           52     9355  Customer_52
# 5           72     8880  Customer_72
# 6           85     8848  Customer_85
# 7           47     8324  Customer_47
# 8           76     8122  Customer_76
# 9           71     7897  Customer_71
